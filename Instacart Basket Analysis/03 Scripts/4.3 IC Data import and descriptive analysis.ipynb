# %% [markdown]
# # Importing a Data Set in Jupyter

# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing dataframe orders.csv
df = pd.read_csv(r'C:\Users\zwier\anaconda_projects\15-01-2025 Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
# Importing dataframe products.csv
df = pd.read_csv(r'C:\Users\zwier\anaconda_projects\15-01-2025 Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
# Creating a path
path = r'C:\Users\zwier\anaconda_projects\15-01-2025 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\zwier\\anaconda_projects\\15-01-2025 Instacart Basket Analysis'

# %%
# Dataframe
df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
print(df)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# importing DF with os.path.join
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %% [markdown]
# # Exploring Data with Pandas

# %%
# start of dataframe
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# start of dataframe 30 lines
df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# end of dataframe
df.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
# end of dataframe 30 lines
df.tail(30)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421053   2789700   206208    prior            35          3
# 3421054    844592   206208    prior            36          6
# 3421055   1541132   206208    prior            37          2
# 3421056   2808240   206208    prior            38          0
# 3421057   3027766   206208    prior            39          2
# 3421058   3356245   206208    prior            40          5
# 3421059    442304   206208    prior            41          2
# 3421060   2675140   206208    prior            42          1
# 3421061    167903   206208    prior            43          4
# 3421062   2393201   206208    prior            44          6
# 3421063   3292671   206208    prior            45          2
# 3421064   3059777   206208    prior            46          1
# 3421065   2239861   206208    prior            47          3
# 3421066   1285346   206208    prior            48          1
# ...

# %%
# dimensions
df.shape
# Out:
# (3421083, 7)

# %%
# basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
# data types
df.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
#  titles of your columns
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# descriptive statistics
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# # Python Data Structures: Lists

# %%
# small part of the data set- limit 1000 rows
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), nrows=1000)

# %%
# check i we do have 1k rows
df
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     2539329        1    prior             1          2                  8
# 1     2398795        1    prior             2          3                  7
# 2      473747        1    prior             3          3                 12
# 3     2254736        1    prior             4          4                  7
# 4      431534        1    prior             5          4                 15
# ..        ...      ...      ...           ...        ...                ...
# 995   2302602       64    prior             7          5                 20
# 996   3215917       64    prior             8          6                 17
# 997   2754807       64    prior             9          6                 15
# 998   3129760       64    prior            10          1                 10
# 999   2639013       64    train            11          0                 13
#
#      days_since_prior_order
# ...

# %%
# unnecessary columns not icluded
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# seting DF with the vars_list filter
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
# checking the results if "eval_set" is filtered out
df
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # Including a Newline Character in a String Using Raw String

# %%
# normal string
s = 'Hi\nHello'

# %%
print(s)
# Out:
# Hi
# Hello

# %%
# raw string
raw_s = r'Hi\nHello'

# %%
print(raw_s)
# Out:
# Hi\nHello

# %%
path = r"C:\Users\Zibi\Documents"

# %%
print(path)
# Out:
# C:\Users\Zibi\Documents

# %%
# Always add second backslash "\" or it will be an error
text = r"C:\Users\Zibi\Documents\"
# Out:
#   Cell In[36], line 2
#     text = r"C:\Users\Zibi\Documents\"
#            ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# Like this
text = r"C:\Users\Zibi\Documents\\"

# %%
print(text)
# Out:
# C:\Users\Zibi\Documents\\
