# %% [markdown]
# # Dealing with MemoryErrors

# %% [markdown]
# If you're looking ar this script, you've probably run into a MemoryError in Jupyter 😥. Not to worry - we've got you sorted! Experiencing a MemoryError means your machine can't allocate enough RAM in order to perform some hefty task. Very often these errors happen when dealing with pandas because it's hardcoded to use only one of the processor cores. In this script you'll find a couple of ways to circumvent these issues.
#
#
#
# ⚠️ Before you start running any of this code, please make sure of the following though:
# - Often times we run into MemoryErros because there are many open notebooks in Jupyter. Every open notebook "steals" RAM!
# - Go to the tab Running in the Jupyter homepage and check how many notebooks are open - they would look green.
# - If you notice notebooks glaring in green that you don't need, you should close them. To do this correctly go to the notebook in question and navigate to the File menu. From there choose Close and halt.
# - Once you've closed the unnecessary notebooks, restart the kernel in the notebook you're working in. NB: save your work e.g. export all data you've manipulated somehow, because restarting the kernel would wipe everything stored in the memory.
# - If that doesn't work, try restarting Python and restarting your browser.
# - In general, try not to have many browser tabs open as well as active programs on your machine (for example, large Excel files).

# %% [markdown]
# ## Contents
#
# #####  <span style="color:blue"> **Plan A** </span>
# In this scenario we'll try to alter the variable types in order to reduce the memory used.
#
# ##### <span style="color:blue"> Plan B </span>
# If plan A doesn't work, combine it with Plan B. Here we'll merge the data sets chunkwise. Plan A and B are to be combined if Plan A alobe doesn't suffice.
#
# ##### <span style="color:blue"> Plan C  </span>
# If both plan A and B don't work, we'll resort to a completely different strategy that invloves installing a new library called Terality. You can still use the modified data from Plan A though.

# %% [markdown]
# ### <span style="color:blue"> Plan A </span>

# %% [markdown]
# In the following code we've experimented and come up with the data types that save the most memory. Don't worry if not all of the columns are familiar to you - some of them are only derived in 4.9. If you're in 4.6 you wouldn't have derived them yet. Feel free to comment out the lines not relevant to you (Ctrl+/).

# %%
import os
import numpy as np
import pandas as pd

# %%
# Set path
path = r'C:\Users\asus\Documents\Instacart Basket Analysis'

# %%
# Import the existing data - NB these data set is just example data sets for 4.6, do use the ones you need to be merged

ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = None)
ords_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col = None)

# %%
ords.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'order_dow', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
ords.drop(columns = {'eval_set', 'Unnamed: 0'}, inplace = True)

# %%
ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
ords.rename(columns = {'order_dow':'orders_day_of_week', 'order_hour_of_day':'order_time_of_day'}, inplace = True)

# %%
ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_time_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
ords_prods.columns
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='object')

# %%
ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_time_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(5)
# memory usage: 156.6 MB

# %%
# Change types for ords data set

ords['order_id']=ords['order_id'].astype('int32')
ords['user_id'] = ords['user_id'].astype('int32')
ords['order_number']=ords['order_number'].astype('int8')
ords['orders_day_of_week']=ords['orders_day_of_week'].astype('int8')
ords['order_time_of_day']=ords['order_time_of_day'].astype('int8')
ords['days_since_prior_order']=ords['days_since_prior_order'].astype('float16')

# %%
# Check output to see memory usage

ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   orders_day_of_week      int8
#  4   order_time_of_day       int8
#  5   days_since_prior_order  float16
# dtypes: float16(1), int32(2), int8(3)
# memory usage: 42.4 MB

# %%
ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
# Change types for ords prods data set 

ords_prods['product_id'] =ords_prods['product_id'].astype('int32')
ords_prods['reordered']=ords_prods['reordered'].astype('int8')
ords_prods['add_to_cart_order']=ords_prods['add_to_cart_order'].astype('int32')
ords_prods['order_id']=ords_prods['order_id'].astype('int32')

# %%
ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int32
#  1   product_id         int32
#  2   add_to_cart_order  int32
#  3   reordered          int8
# dtypes: int32(3), int8(1)
# memory usage: 402.1 MB

# %%
# Further columns from other data sets

df['aisle_id'] = df['aisle_id'].astype('int8')
df['department_id'] = df['department_id'].astype('int8')
df['prices'] = df['prices'].astype('float16')
df['age'] = df['age'].astype('int8')
df['n_dependants'] = df['n_dependants'].astype('int8')
df['income'] = df['income'].astype('int8')

# %% [markdown]
# NB: in the code above not all columns are listed. You may have derived some additional columns - mainly flags - that are not reflected above. Keep in mind the following:
# - flags should be objects
# - avoid int64 data type because it consumes a lot of memory. Try int32 or int8.
# - After every take run `info()` to see how much the memory usage decreased (in the bottom) but also `head()` because some of these changes may affect the data!

# %%
# Attemp a merge

ords_prods_merged = ords.merge(ords_prods, on = ['order_id'], how = 'outer', indicator = True)

# %%
ords_prods_merged['_merge'].value_counts(dropna = False)
# Out:
# both          32434489
# left_only       206209
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ### <span style="color:blue"> Plan B </span>

# %% [markdown]
# In this plan we'll merge the 2 dataframe (with the altered data types) using a chunkwise method. This means we'll split the large data frame into chunks and merge them piece by piece to the smaller dataframe.

# %%
# df1 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))
# df2 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col = None)

# %%
# %%time

ords_prods_key = ords_prods['order_id']

# Creating an empty shell to save the result
df_result = pd.DataFrame(columns=(ords.columns.append(ords_prods.columns)).unique())
df_result.to_csv(os.path.join(path, '02 Data', 'Prepared Data', "df3.csv"),index_label=False)

# Deleting ords_prods to save memory (the large one)
del(ords_prods)

# The basic idea is that we'll now load the large data set into chunks and then create a function that will 
# iteratively merge those chunks to the main data set 


# Define a function that will merge the chunks
def preprocess(x):
    ords_prods = pd.merge(ords,x, left_on = "order_id", right_on = "order_id")
    ords_prods.to_csv(os.path.join(path, '02 Data', 'Prepared Data', "df3.csv"),mode="a",header=False,index=False)

    
reader = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), chunksize=10000) # chunksize depends on you colsize

[preprocess(r) for r in reader]
# Out:
# Wall time: 42min 24s
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
# Import the result to see what happened 

df_test = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df3.csv'))

# %%
df_test.shape
# Out:
# (32434489, 11)

# %%
df_test.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0        6226        40      382    prior            29          1
# 1        6226        40      382    prior            29          1
# 2        6226        40      382    prior            29          1
# 3        6226        40      382    prior            29          1
# 4        8161       214      503    prior             5          0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                 15                    23.0       10070                  1
# 1                 15                    23.0       42450                  2
# 2                 15                    23.0       33198                  3
# 3                 15                    23.0       34866                  4
# 4                 16                     9.0        5499                  1
#
#    reordered
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0

# %%
df_test.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'order_dow', 'order_hour_of_day', 'days_since_prior_order',
#        'product_id', 'add_to_cart_order', 'reordered'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'order_dow', 'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %% [markdown]
# #### Try with the 4.9 data set

# %%
orders_products_merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.csv'))

# %%
cust = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'cust_data_final.csv'))

# %%
orders_products_merged.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'product_id', 'add_to_cart_order',
#        'reordered', 'product_name', 'aisle_id', 'department_id', '_merge'],
#       dtype='object')

# %%
cust.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
# %%time
df4_key = orders_products_merged['user_id']

# creating a empty bucket to save result
df_result = pd.DataFrame(columns=(cust.columns.append(orders_products_merged.columns)).unique())
df_result.to_csv(os.path.join(path, '02 Data', 'Prepared Data', "df_result_3.csv"),index_label=False)

# deleting df2 to save memory
del(orders_products_merged)

def preprocess(x):
    df5=pd.merge(cust,x, left_on = "user_id", right_on = "user_id")
    df5.to_csv(os.path.join(path, '02 Data', 'Prepared Data', "df_result_3.csv"),mode="a",header=False,index=False)

reader = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.csv'), chunksize=10000) # chunksize depends with you colsize

[preprocess(r) for r in reader]
# Out:
# Wall time: 7min 23s
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
# Check the result

df_test = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_result_3.csv'))

# %%
df_test.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income', 'order_id',
#        'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order', 'product_id', 'add_to_cart_order',
#        'reordered', 'product_name', 'aisle_id', 'department_id', '_merge'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (32434489, 22)

# %% [markdown]
# ### <span style="color:blue"> Plan C </span>

# %% [markdown]
# #### Setup

# %% [markdown]
# First, click [here](https://app.terality.com/) and follow the instructions.Here's a recap:
#
# - Create an account
# - Install terality by typing `pip install --upgrade terality` in the command prompt/terminal/Jupyter
# - Get and save your API key somewhere
# - Configure the terality library in the command prompt/terminal (or in Jupyter as per the instructions in the webpage)
#
#
# Terality allows 1000GB data usage per month. This is actually quite a lot and the good news is that once you upload a data set onto their server, it stays there - meaning you it doesn't get reuploaded when you run the same script again and taking up more space from your data plan.

# %% [markdown]
# _*This script builds onto the tutorial script from Terality's website. The first part has been added as an example of how you can use it if you're facing difficulties with the size of the data sets in the Instacart project._

# %% [markdown]
# ## First steps - data upload

# %% [markdown]
# Terality exposes dataframes and other data structures with exactly the same API as pandas. No need to learn a new framework, just import the package and start processing data exactly as in pandas!

# %%
import terality as te # the new library
# Out:
# You are using version 0.14.3 of the Terality client, but version 0.14.14 is available. Consider upgrading your version to get the latest fixes and features.

# %%
pip install --upgrade terality
# Out:
# Requirement already satisfied: terality in c:\users\asus\anaconda3\lib\site-packages (0.14.3)
# Collecting terality
#   Downloading terality-0.14.14-py3-none-any.whl (152 kB)
#      -------------------------------------- 152.5/152.5 KB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: boto3>=1.16.28 in c:\users\asus\anaconda3\lib\site-packages (from terality) (1.21.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.45.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (4.46.0)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (1.0.3)
# Requirement already satisfied: sentry-sdk<2.0.0,>=1.3.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (1.5.6)
# Requirement already satisfied: click<9,>=3.2 in c:\users\asus\anaconda3\lib\site-packages (from terality) (8.0.4)
# Requirement already satisfied: numpy<2.0,>=1.18 in c:\users\asus\anaconda3\lib\site-packages (from terality) (1.18.1)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: protobuf<4.0.0,>=3.9.1 in c:\users\asus\anaconda3\lib\site-packages (from terality) (3.12.1)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\asus\anaconda3\lib\site-packages)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\asus\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pyarrow<7.0.0,>=6.0.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (6.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (2.23.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.7.3 in c:\users\asus\anaconda3\lib\site-packages (from terality) (1.9.0)
# Requirement already satisfied: importlib_metadata<5,>=3.0 in c:\users\asus\anaconda3\lib\site-packages (from terality) (3.10.1)
# Requirement already satisfied: botocore<1.25.0,>=1.24.8 in c:\users\asus\anaconda3\lib\site-packages (from boto3>=1.16.28->terality) (1.24.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\asus\anaconda3\lib\site-packages (from boto3>=1.16.28->terality) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\asus\anaconda3\lib\site-packages (from boto3>=1.16.28->terality) (0.5.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from click<9,>=3.2->terality) (0.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\asus\anaconda3\lib\site-packages (from importlib_metadata<5,>=3.0->terality) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\asus\anaconda3\lib\site-packages (from importlib_metadata<5,>=3.0->terality) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.0.0->terality) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.0.0->terality) (2020.1)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from protobuf<4.0.0,>=3.9.1->terality) (47.1.1.post20200604)
# Requirement already satisfied: six>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from protobuf<4.0.0,>=3.9.1->terality) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->terality) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->terality) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->terality) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->terality) (1.25.8)
# Installing collected packages: terality
#   Attempting uninstall: terality
#     Found existing installation: terality 0.14.3
#     Uninstalling terality-0.14.3:
#       Successfully uninstalled terality-0.14.3
# Successfully installed terality-0.14.14

# %% [markdown]
#  An easy way to get started and create a `terality.DataFrame` is by importing a `pandas.DataFrame` using the function `from_pandas`:

# %%
df_te_ords_p = te.DataFrame.from_pandas(ords_prods)
df_te_ords = te.DataFrame.from_pandas(ords)
# Out:
# uploading data:   0%|                                                                       | 0.00/121M [00:00<?, ?B/s]
# uploading data:   0%|▏                                                               | 262k/121M [00:00<05:53, 340kB/s]
# uploading data:   0%|▎                                                               | 524k/121M [00:01<04:58, 402kB/s]
# uploading data:   1%|▊                                                             | 1.57M/121M [00:01<01:55, 1.03MB/s]
# uploading data:   1%|▊                                                             | 1.57M/121M [00:01<01:55, 1.03MB/s]
# uploading data:   1%|▊                                                             | 1.57M/121M [00:01<01:55, 1.03MB/s]
# uploading data:   3%|█▌                                                            | 3.15M/121M [00:01<01:29, 1.32MB/s]
# uploading data:   4%|██▍                                                           | 4.72M/121M [00:01<00:48, 2.39MB/s]
# uploading data:   4%|██▌                                                           | 4.98M/121M [00:01<00:48, 2.39MB/s]
# uploading data:   5%|███▏                                                          | 6.29M/121M [00:02<00:47, 2.42MB/s]
# uploading data:   5%|███▏                                                          | 6.29M/121M [00:02<00:47, 2.42MB/s]
# uploading data:   7%|████▎                                                         | 8.39M/121M [00:02<00:43, 2.58MB/s]
# uploading data:   8%|████▊                                                         | 9.44M/121M [00:03<00:33, 3.31MB/s]
# uploading data:   9%|█████▋                                                        | 11.0M/121M [00:03<00:26, 4.13MB/s]
# uploading data:  10%|██████                                                        | 11.8M/121M [00:03<00:23, 4.69MB/s]
# uploading data:  11%|██████▋                                                       | 13.1M/121M [00:03<00:23, 4.61MB/s]
# uploading data:  12%|███████▏                                                      | 13.9M/121M [00:03<00:21, 4.86MB/s]
# uploading data:  12%|███████▌                                                      | 14.7M/121M [00:03<00:23, 4.55MB/s]
# uploading data:  13%|███████▉                                                      | 15.5M/121M [00:04<00:22, 4.77MB/s]
# uploading data:  14%|████████▍                                                     | 16.5M/121M [00:04<00:20, 5.02MB/s]
# uploading data:  14%|████████▍                                                     | 16.5M/121M [00:04<00:20, 5.02MB/s]
# uploading data:  14%|████████▉                                                     | 17.3M/121M [00:04<00:19, 5.43MB/s]
# uploading data:  15%|█████████▎                                                    | 18.1M/121M [00:04<00:18, 5.56MB/s]
# uploading data:  16%|█████████▊                                                    | 19.1M/121M [00:04<00:17, 5.75MB/s]
# uploading data:  17%|██████████▏                                                   | 19.9M/121M [00:04<00:18, 5.50MB/s]
# uploading data:  17%|██████████▊                                                   | 21.0M/121M [00:04<00:16, 5.97MB/s]
# uploading data:  18%|███████████▎                                                  | 22.0M/121M [00:05<00:17, 5.79MB/s]
# uploading data:  19%|███████████▊                                                  | 23.1M/121M [00:05<00:18, 5.27MB/s]
# uploading data:  19%|███████████▊                                                  | 23.1M/121M [00:05<00:18, 5.27MB/s]
# uploading data:  20%|████████████▎                                                 | 23.9M/121M [00:05<00:18, 5.30MB/s]
# uploading data:  20%|████████████▋                                                 | 24.6M/121M [00:05<00:18, 5.29MB/s]
# uploading data:  21%|█████████████▏                                                | 25.7M/121M [00:05<00:16, 5.71MB/s]
# uploading data:  22%|█████████████▌                                                | 26.5M/121M [00:05<00:19, 4.87MB/s]
# uploading data:  23%|██████████████▏                                               | 27.5M/121M [00:06<00:16, 5.77MB/s]
# uploading data:  23%|██████████████▌                                               | 28.3M/121M [00:06<00:17, 5.13MB/s]
# uploading data:  24%|██████████████▉                                               | 29.1M/121M [00:06<00:16, 5.46MB/s]
# uploading data:  25%|███████████████▌                                              | 30.1M/121M [00:06<00:19, 4.65MB/s]
# uploading data:  25%|███████████████▌                                              | 30.1M/121M [00:06<00:19, 4.65MB/s]
# uploading data:  26%|███████████████▉                                              | 30.9M/121M [00:06<00:17, 5.06MB/s]
# uploading data:  26%|████████████████▎                                             | 31.7M/121M [00:06<00:17, 5.09MB/s]
# uploading data:  27%|████████████████▋                                             | 32.5M/121M [00:07<00:25, 3.52MB/s]
# uploading data:  28%|█████████████████                                             | 33.3M/121M [00:07<00:23, 3.66MB/s]
# uploading data:  28%|█████████████████▋                                            | 34.3M/121M [00:07<00:22, 3.77MB/s]
# uploading data:  29%|██████████████████                                            | 35.1M/121M [00:07<00:19, 4.39MB/s]
# uploading data:  30%|██████████████████▎                                           | 35.7M/121M [00:07<00:19, 4.33MB/s]
# uploading data:  30%|██████████████████▌                                           | 36.2M/121M [00:08<00:21, 3.90MB/s]
# uploading data:  31%|███████████████████▎                                          | 37.5M/121M [00:08<00:18, 4.57MB/s]
# uploading data:  31%|███████████████████▍                                          | 37.7M/121M [00:08<00:15, 5.38MB/s]
# uploading data:  32%|███████████████████▊                                          | 38.5M/121M [00:08<00:16, 4.97MB/s]
# uploading data:  33%|████████████████████▏                                         | 39.3M/121M [00:08<00:16, 5.05MB/s]
# uploading data:  33%|████████████████████▊                                         | 40.4M/121M [00:08<00:15, 5.27MB/s]
# uploading data:  34%|█████████████████████▎                                        | 41.4M/121M [00:09<00:14, 5.59MB/s]
# uploading data:  35%|█████████████████████▋                                        | 42.2M/121M [00:09<00:13, 5.76MB/s]
# uploading data:  36%|██████████████████████                                        | 43.0M/121M [00:09<00:14, 5.23MB/s]
# uploading data:  36%|██████████████████████▌                                       | 43.8M/121M [00:09<00:14, 5.31MB/s]
# uploading data:  37%|██████████████████████▉                                       | 44.6M/121M [00:09<00:13, 5.75MB/s]
# uploading data:  38%|███████████████████████▍                                      | 45.6M/121M [00:09<00:12, 5.78MB/s]
# uploading data:  38%|███████████████████████▊                                      | 46.4M/121M [00:09<00:13, 5.33MB/s]
# uploading data:  39%|████████████████████████▎                                     | 47.2M/121M [00:10<00:14, 5.02MB/s]
# uploading data:  40%|████████████████████████▊                                     | 48.2M/121M [00:10<00:14, 4.97MB/s]
# uploading data:  41%|█████████████████████████▌                                    | 49.8M/121M [00:10<00:11, 6.14MB/s]
# uploading data:  41%|█████████████████████████▌                                    | 49.8M/121M [00:10<00:11, 6.14MB/s]
# uploading data:  42%|██████████████████████████▏                                   | 50.9M/121M [00:10<00:10, 6.40MB/s]
# uploading data:  43%|██████████████████████████▌                                   | 51.6M/121M [00:10<00:14, 4.74MB/s]
# uploading data:  43%|██████████████████████████▉                                   | 52.4M/121M [00:11<00:13, 5.18MB/s]
# uploading data:  44%|███████████████████████████▎                                  | 53.2M/121M [00:11<00:14, 4.78MB/s]
# uploading data:  45%|███████████████████████████▊                                  | 54.0M/121M [00:11<00:13, 5.00MB/s]
# uploading data:  46%|████████████████████████████▎                                 | 55.1M/121M [00:11<00:11, 5.75MB/s]
# uploading data:  46%|████████████████████████████▋                                 | 55.8M/121M [00:11<00:11, 5.85MB/s]
# uploading data:  47%|█████████████████████████████                                 | 56.6M/121M [00:11<00:12, 5.01MB/s]
# uploading data:  48%|█████████████████████████████▉                                | 58.2M/121M [00:12<00:11, 5.58MB/s]
# uploading data:  49%|██████████████████████████████▎                               | 59.0M/121M [00:12<00:11, 5.33MB/s]
# uploading data:  50%|██████████████████████████████▋                               | 59.8M/121M [00:12<00:10, 5.85MB/s]
# uploading data:  50%|███████████████████████████████▎                              | 60.8M/121M [00:12<00:13, 4.58MB/s]
# uploading data:  50%|███████████████████████████████▎                              | 60.8M/121M [00:12<00:13, 4.58MB/s]
# uploading data:  51%|███████████████████████████████▌                              | 61.3M/121M [00:12<00:13, 4.56MB/s]
# uploading data:  51%|███████████████████████████████▊                              | 61.9M/121M [00:12<00:12, 4.72MB/s]
# uploading data:  52%|████████████████████████████████▎                             | 62.9M/121M [00:12<00:09, 5.86MB/s]
# uploading data:  52%|████████████████████████████████▎                             | 62.9M/121M [00:12<00:09, 5.86MB/s]
# uploading data:  53%|████████████████████████████████▊                             | 63.7M/121M [00:13<00:12, 4.59MB/s]
# uploading data:  53%|█████████████████████████████████▏                            | 64.5M/121M [00:13<00:10, 5.21MB/s]
# uploading data:  54%|█████████████████████████████████▋                            | 65.5M/121M [00:13<00:09, 6.08MB/s]
# uploading data:  55%|██████████████████████████████████                            | 66.3M/121M [00:13<00:10, 5.18MB/s]
# uploading data:  56%|██████████████████████████████████▌                           | 67.1M/121M [00:13<00:13, 4.08MB/s]
# uploading data:  57%|███████████████████████████████████▏                          | 68.4M/121M [00:14<00:11, 4.61MB/s]
# uploading data:  58%|███████████████████████████████████▋                          | 69.5M/121M [00:14<00:09, 5.28MB/s]
# uploading data:  58%|████████████████████████████████████▎                         | 70.5M/121M [00:14<00:09, 5.46MB/s]
# uploading data:  59%|████████████████████████████████████▋                         | 71.3M/121M [00:14<00:08, 5.54MB/s]
# uploading data:  60%|█████████████████████████████████████                         | 72.1M/121M [00:14<00:09, 5.30MB/s]
# uploading data:  60%|█████████████████████████████████████▍                        | 72.9M/121M [00:14<00:10, 4.77MB/s]
# uploading data:  61%|█████████████████████████████████████▉                        | 73.7M/121M [00:14<00:08, 5.26MB/s]
# uploading data:  62%|██████████████████████████████████████▍                       | 74.7M/121M [00:15<00:07, 5.77MB/s]
# uploading data:  63%|██████████████████████████████████████▊                       | 75.5M/121M [00:15<00:08, 5.22MB/s]
# uploading data:  63%|███████████████████████████████████████▏                      | 76.3M/121M [00:15<00:09, 4.92MB/s]
# uploading data:  64%|███████████████████████████████████████▋                      | 77.1M/121M [00:15<00:08, 5.13MB/s]
# uploading data:  65%|████████████████████████████████████████                      | 77.9M/121M [00:15<00:08, 5.10MB/s]
# uploading data:  65%|████████████████████████████████████████▍                     | 78.6M/121M [00:15<00:07, 5.50MB/s]
# uploading data:  66%|█████████████████████████████████████████                     | 80.0M/121M [00:16<00:06, 6.08MB/s]
# uploading data:  67%|█████████████████████████████████████████▌                    | 80.7M/121M [00:16<00:07, 5.07MB/s]
# uploading data:  68%|█████████████████████████████████████████▉                    | 81.5M/121M [00:16<00:07, 4.93MB/s]
# uploading data:  68%|██████████████████████████████████████████▎                   | 82.3M/121M [00:16<00:06, 5.53MB/s]
# uploading data:  69%|██████████████████████████████████████████▋                   | 83.1M/121M [00:16<00:06, 5.77MB/s]
# uploading data:  70%|███████████████████████████████████████████▏                  | 83.9M/121M [00:16<00:06, 5.33MB/s]
# uploading data:  70%|███████████████████████████████████████████▌                  | 84.7M/121M [00:17<00:07, 4.98MB/s]
# uploading data:  71%|███████████████████████████████████████████▉                  | 85.5M/121M [00:17<00:06, 5.29MB/s]
# uploading data:  72%|████████████████████████████████████████████▍                 | 86.5M/121M [00:17<00:05, 5.76MB/s]
# uploading data:  72%|████████████████████████████████████████████▉                 | 87.3M/121M [00:17<00:06, 5.12MB/s]
# uploading data:  73%|█████████████████████████████████████████████▎                | 88.1M/121M [00:17<00:06, 5.29MB/s]
# uploading data:  74%|█████████████████████████████████████████████▋                | 88.9M/121M [00:17<00:05, 5.43MB/s]
# uploading data:  74%|██████████████████████████████████████████████                | 89.7M/121M [00:17<00:05, 5.24MB/s]
# uploading data:  75%|██████████████████████████████████████████████▋               | 90.7M/121M [00:18<00:05, 5.94MB/s]
# uploading data:  76%|███████████████████████████████████████████████               | 91.5M/121M [00:18<00:05, 5.14MB/s]
# uploading data:  77%|███████████████████████████████████████████████▍              | 92.3M/121M [00:18<00:05, 5.31MB/s]
# uploading data:  77%|███████████████████████████████████████████████▊              | 93.1M/121M [00:18<00:04, 5.53MB/s]
# uploading data:  78%|████████████████████████████████████████████████▎             | 93.8M/121M [00:18<00:04, 5.74MB/s]
# uploading data:  78%|████████████████████████████████████████████████▋             | 94.6M/121M [00:18<00:05, 5.12MB/s]
# uploading data:  79%|█████████████████████████████████████████████████             | 95.4M/121M [00:19<00:05, 4.60MB/s]
# uploading data:  80%|█████████████████████████████████████████████████▍            | 96.2M/121M [00:19<00:04, 5.25MB/s]
# uploading data:  80%|█████████████████████████████████████████████████▌            | 96.5M/121M [00:19<00:03, 6.16MB/s]
# uploading data:  81%|██████████████████████████████████████████████████            | 97.3M/121M [00:19<00:04, 5.60MB/s]
# uploading data:  81%|██████████████████████████████████████████████████▍           | 98.0M/121M [00:19<00:03, 5.93MB/s]
# uploading data:  82%|██████████████████████████████████████████████████▊           | 98.8M/121M [00:19<00:03, 5.83MB/s]
# uploading data:  83%|███████████████████████████████████████████████████▏          | 99.6M/121M [00:19<00:04, 4.82MB/s]
# uploading data:  84%|████████████████████████████████████████████████████▋          | 101M/121M [00:20<00:03, 5.08MB/s]
# uploading data:  85%|█████████████████████████████████████████████████████▎         | 102M/121M [00:20<00:03, 5.73MB/s]
# uploading data:  85%|█████████████████████████████████████████████████████▋         | 103M/121M [00:20<00:03, 4.62MB/s]
# uploading data:  86%|██████████████████████████████████████████████████████         | 104M/121M [00:20<00:03, 4.37MB/s]
# uploading data:  87%|██████████████████████████████████████████████████████▋        | 105M/121M [00:20<00:03, 4.35MB/s]
# uploading data:  88%|███████████████████████████████████████████████████████▏       | 106M/121M [00:21<00:03, 4.51MB/s]
# uploading data:  88%|███████████████████████████████████████████████████████▋       | 107M/121M [00:21<00:02, 4.66MB/s]
# uploading data:  89%|████████████████████████████████████████████████████████▎      | 108M/121M [00:21<00:02, 4.84MB/s]
# uploading data:  90%|████████████████████████████████████████████████████████▊      | 109M/121M [00:21<00:02, 5.01MB/s]
# uploading data:  91%|█████████████████████████████████████████████████████████▏     | 110M/121M [00:21<00:01, 5.53MB/s]
# uploading data:  92%|█████████████████████████████████████████████████████████▋     | 110M/121M [00:21<00:01, 5.88MB/s]
# uploading data:  92%|██████████████████████████████████████████████████████████     | 111M/121M [00:21<00:01, 5.77MB/s]
# uploading data:  93%|██████████████████████████████████████████████████████████▍    | 112M/121M [00:22<00:02, 3.38MB/s]
# uploading data:  94%|███████████████████████████████████████████████████████████    | 113M/121M [00:22<00:01, 4.00MB/s]
# uploading data:  94%|███████████████████████████████████████████████████████████▍   | 114M/121M [00:22<00:01, 4.48MB/s]
# uploading data:  95%|███████████████████████████████████████████████████████████▊   | 115M/121M [00:22<00:01, 5.05MB/s]
# uploading data:  96%|████████████████████████████████████████████████████████████▎  | 115M/121M [00:22<00:00, 5.35MB/s]
# uploading data:  96%|████████████████████████████████████████████████████████████▋  | 116M/121M [00:23<00:00, 5.45MB/s]
# uploading data:  97%|█████████████████████████████████████████████████████████████▏ | 117M/121M [00:23<00:00, 5.58MB/s]
# uploading data:  98%|█████████████████████████████████████████████████████████████▋ | 118M/121M [00:23<00:00, 5.29MB/s]
# uploading data:  98%|██████████████████████████████████████████████████████████████ | 119M/121M [00:23<00:00, 5.33MB/s]
# uploading data:  99%|██████████████████████████████████████████████████████████████▍| 120M/121M [00:23<00:00, 5.26MB/s]
# uploading data: 100%|██████████████████████████████████████████████████████████████▊| 120M/121M [00:24<00:00, 3.59MB/s]
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\encoder.py in _upload_object_and_get_metadata(credentials_fetcher, upload_method, obj)
#     305     try:
# --> 306         return upload_method(credentials_fetcher, obj)
#     307     except pyarrow.lib.ArrowNotImplementedError as e:
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\encoder.py in _upload_df_and_get_metadata(aws_credentials, df)
#     266     df_for_upload = df.copy(deep=True)
# --> 267     transfer_id, metadata = _encode_inplace_and_upload_df(aws_credentials, df_for_upload)
#     268     return PandasDFMetadata(transfer_id, metadata)
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\encoder.py in _encode_inplace_and_upload_df(aws_credentials, df)
#     113     data_bytes = BytesIO()
# --> 114     df.to_parquet(data_bytes, engine="pyarrow", version="2.6", row_group_size=row_group_size)
#     115     memory_parquet_size = data_bytes.getbuffer().nbytes
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_parquet(self, path, engine, compression, index, partition_cols, **kwargs)
#    2115             partition_cols=partition_cols,
# -> 2116             **kwargs,
#    2117         )
#
# ~\Anaconda3\lib\site-packages\pandas\io\parquet.py in to_parquet(df, path, engine, compression, index, partition_cols, **kwargs)
#     263         partition_cols=partition_cols,
# --> 264         **kwargs,
#     265     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\parquet.py in write(self, df, path, compression, coerce_timestamps, index, partition_cols, **kwargs)
#     116                 coerce_timestamps=coerce_timestamps,
# --> 117                 **kwargs,
#     118             )
#
# ~\Anaconda3\lib\site-packages\pyarrow\parquet.py in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, data_page_version, use_compliant_nested_type, **kwargs)
#    2032                 use_compliant_nested_type=use_compliant_nested_type,
# -> 2033                 **kwargs) as writer:
#    2034             writer.write_table(table, row_group_size=row_group_size)
#
# ~\Anaconda3\lib\site-packages\pyarrow\parquet.py in __init__(self, where, schema, filesystem, flavor, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, compression_level, use_byte_stream_split, writer_engine_version, data_page_version, use_compliant_nested_type, **options)
#     674             use_compliant_nested_type=use_compliant_nested_type,
# --> 675             **options)
#     676         self.is_open = True
#
# ~\Anaconda3\lib\site-packages\pyarrow\_parquet.pyx in pyarrow._parquet.ParquetWriter.__cinit__()
#
# ~\Anaconda3\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Unhandled type for Arrow to Parquet schema conversion: halffloat
#
# The above exception was the direct cause of the following exception:
#
# TeralityClientError                       Traceback (most recent call last)
# <ipython-input-41-3ee5f7951c11> in <module>
#       1 df_te_ords_p = te.DataFrame.from_pandas(ords_prods)
# ----> 2 df_te_ords = te.DataFrame.from_pandas(ords)
#       3
#       4 # In the output here you see 0% progress because the data had already been uploaded in Terality's servers. In your case
#       5 # when you upload data for the first time you'll see the % progress get up to 100.
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\dataframe.py in from_pandas(cls, df)
#     314             max_cols=max_cols,
#     315             memory_usage=memory_usage,
# --> 316             null_counts=null_counts,
#     317         )
#     318         print(info)
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\structure.py in _call(cls, accessor, func_name, *args, **kwargs)
#      73     _pandas_class_instance: Any = None
#      74     _additional_methods: Set[str] = {
# ---> 75         "to_pandas",
#      76         "load",
#      77         "save",
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\pandas_job.py in call_pandas_function(function_type, function_prefix, function_name, *args, **kwargs)
#      18 ) -> Any:
#      19
# ---> 20     # Disable override within terality client code. See `disable_override_for_external_libs` docstring for details.
#      21     with _disable_patching_external_packages():
#      22
#
# ~\Anaconda3\lib\site-packages\terality_serde\recursive_apply.py in apply_func_on_object_recursively(obj, f, apply_on_key_dict)
#       8     if isinstance(obj, tuple):  # pylint: disable=no-else-return
#       9         return tuple(  # pylint: disable=consider-using-generator
# ---> 10             [apply_func_on_object_recursively(value, f, apply_on_key_dict) for value in obj]
#      11         )
#      12     elif isinstance(obj, dict):
#
# ~\Anaconda3\lib\site-packages\terality_serde\recursive_apply.py in <listcomp>(.0)
#       8     if isinstance(obj, tuple):  # pylint: disable=no-else-return
#       9         return tuple(  # pylint: disable=consider-using-generator
# ---> 10             [apply_func_on_object_recursively(value, f, apply_on_key_dict) for value in obj]
#      11         )
#      12     elif isinstance(obj, dict):
#
# ~\Anaconda3\lib\site-packages\terality_serde\recursive_apply.py in apply_func_on_object_recursively(obj, f, apply_on_key_dict)
#      18         }
#      19     else:
# ---> 20         return f(obj)
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\encoder.py in encode(credentials_fetcher, function_name, obj)
#     331         upload_method = _get_upload_method(obj)
#     332         if upload_method is not None:
# --> 333             return _upload_object_and_get_metadata(credentials_fetcher, upload_method, obj)
#     334         raise ValueError(f"Can't convert type {type(obj)} to terality structure")
#     335     try:
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\encoder.py in _upload_object_and_get_metadata(credentials_fetcher, upload_method, obj)
#     311         raise TeralityClientError(
#     312             f"Terality can not transfer the data structure: unsupported data type: {message}"
# --> 313         ) from e
#     314
#     315
#
# TeralityClientError: Terality can not transfer the data structure: unsupported data type: halffloat

# %%
df_te_ords.info() 

# Check out the memory usage at the bottom - it's really low! Showing one of the greatest features of Terality.
# Out:
# <class 'terality.DataFrame'>
# Index: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_time_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: int64(5), float64(1)
# memory usage: 182.7 MB (run with deep=True)
# uploading data: 100%|███████████████████████████████████████████████████████████████| 121M/121M [00:37<00:00, 3.59MB/s]

# %% [markdown]
# ## Merging the data

# %%
# %%time 
# this command will show how much time does it take to do the merge. If you want to use it always make sure that 
# it's the very first line of code in the cell

# Merge the 2 data sets

df_2 = df_te_ords_p.merge(df_te_ords, on=["order_id"], how="left", indicator = True)
# Out:
# Wall time: 30.9 s

# %%
df_2.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_time_of_day  days_since_prior_order _merge
# 0                   5                  9                     8.0   both
# 1                   5                  9                     8.0   both
# 2                   5                  9                     8.0   both
# 3                   5                  9                     8.0   both
# 4                   5                  9                     8.0   both

# %%
df_2.shape 

# The result for the rows shows that we have a successful merge.
# Out:
# (32434489, 10)

# %%
df_2['_merge'].value_counts(dropna = False)
# Out:
# both          32434489
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %%
# Let's try to convert the terality dataframe back to a pandas dataframe using the special function to_pandas

df_pd_roundtrip = df_2.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-47-af29fe4c7f9f> in <module>
#       1 # Let's try to convert the terality dataframe back to a pandas dataframe using the special function to_pandas
#       2
# ----> 3 df_pd_roundtrip = df_2.to_pandas()
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\structure.py in _call_method(self, accessor, func_name, *args, **kwargs)
#      81     _indexers = {"iat", "at", "loc", "iloc"}  # put in the mcs to get in the dir?
#      82
# ---> 83     _methods_allowed_to_be_cached: List[str] = []
#      84     _cache: Dict[str, Any]
#      85
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\structure.py in _call(cls, accessor, func_name, *args, **kwargs)
#      73     _pandas_class_instance: Any = None
#      74     _additional_methods: Set[str] = {
# ---> 75         "to_pandas",
#      76         "load",
#      77         "save",
#
# ~\Anaconda3\lib\site-packages\terality\_terality\terality_structures\pandas_job.py in call_pandas_function(function_type, function_prefix, function_name, *args, **kwargs)
#      35             function_name=function_name,
#      36             args_encoded=dumps(args_encoded),
# ---> 37             kwargs_encoded=dumps(kwargs_encoded),
#      38         )
#      39
#
# ~\Anaconda3\lib\site-packages\terality_serde\recursive_apply.py in apply_func_on_object_recursively(obj, f, apply_on_key_dict)
#      18         }
#      19     else:
# ---> 20         return f(obj)
#      21
#      22
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\decoder.py in decode(credentials_fetcher, obj)
#     192         StructType.EXTENSION_ARRAY: ExtensionArray,
#     193         StructType.SERIES: Series,
# --> 194         StructType.DATAFRAME: DataFrame,
#     195         StructType.SERIES_GROUPBY: SeriesGroupBy,
#     196         StructType.DATAFRAME_GROUPBY: DataFrameGroupBy,
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\decoder.py in _download_df_from_metadata(aws_credentials, df_metadata)
#     140 def _download_series_from_metadata(
#     141     aws_credentials: AwsCredentials, series_metadata: PandasSeriesMetadata
# --> 142 ) -> pd.Series:
#     143     df = _download_df(
#     144         aws_credentials, series_metadata.transfer_id, series_metadata.parquet_metadata
#
# ~\Anaconda3\lib\site-packages\terality\_terality\encoding\decoder.py in _download_df(aws_credentials, transfer_id, metadata)
#      73
#      74     # range index get dropped by read_parquet on a df with no cols
# ---> 75     if df.shape[0] == 0:
#      76         file_schema = parquet.read_schema(pyarrow.BufferReader(bytes_io.getvalue()))
#      77         pandas_metadata = file_schema.pandas_metadata
#
# ~\Anaconda3\lib\site-packages\terality\_terality\data_transmitter.py in download_to_bytes(self, aws_credentials, transfer_id)
#     267         Download all parquet files as bytes stored on S3 for a given transfer_id.
#     268         """
# --> 269
#     270         bucket = self._get_download_config().bucket_region()
#     271         prefix = f"{self._get_download_config().key_prefix}{transfer_id}/"
#
# ~\Anaconda3\lib\site-packages\boto3\s3\inject.py in download_fileobj(self, Bucket, Key, Fileobj, ExtraArgs, Callback, Config)
#     793             subscribers=subscribers,
#     794         )
# --> 795         return future.result()
#     796
#     797
#
# ~\Anaconda3\lib\site-packages\s3transfer\futures.py in result(self)
#     101             # however if a KeyboardInterrupt is raised we want want to exit
#     102             # out of this and propagate the exception.
# --> 103             return self._coordinator.result()
#     104         except KeyboardInterrupt as e:
#     105             self.cancel()
#
# ~\Anaconda3\lib\site-packages\s3transfer\futures.py in result(self)
#     264         # final result.
#     265         if self._exception:
# --> 266             raise self._exception
#     267         return self._result
#     268
#
# ~\Anaconda3\lib\site-packages\s3transfer\tasks.py in _main(self, transfer_future, **kwargs)
#     267             # Call the submit method to start submitting tasks to execute the
#     268             # transfer.
# --> 269             self._submit(transfer_future=transfer_future, **kwargs)
#     270         except BaseException as e:
#     271             # If there was an exception raised during the submission of task
#
# ~\Anaconda3\lib\site-packages\s3transfer\download.py in _submit(self, client, config, osutil, request_executor, io_executor, transfer_future, bandwidth_limiter)
#     355                 Bucket=transfer_future.meta.call_args.bucket,
#     356                 Key=transfer_future.meta.call_args.key,
# --> 357                 **transfer_future.meta.call_args.extra_args,
#     358             )
#     359             transfer_future.meta.provide_transfer_size(
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     393                     "%s() only accepts keyword arguments." % py_operation_name)
#     394             # The "self" in this scope is referring to the BaseClient.
# --> 395             return self._make_api_call(operation_name, kwargs)
#     396
#     397         _api_call.__name__ = str(py_operation_name)
#
# ~\Anaconda3\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     723             error_code = parsed_response.get("Error", {}).get("Code")
#     724             error_class = self.exceptions.from_code(error_code)
# --> 725             raise error_class(parsed_response, operation_name)
#     726         else:
#     727             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %% [markdown]
# 😱😱😱
#
# ##### Now that we saw we can't directly save the terality dataframe as a pandas dataframe, we need to resort to a different method. The Terality documentation offers one solution we can try:
# - Save the merged dataframe by partitioning as multiple parquet files (the terality special data format)
# - Import the parquet files in the Jupyter memory
# - Convert these smaller pieces to pandas dataframes as this will require less memory
# - Concatinate the dataframes
#
#
# ####  😈 <span style="color:red"> The upcoming sections contain the splitting into multiple files, which requires writing very similar names multiple times. This is very tedious. In order to save you time we have created an Excel Helper file that you can download from Exercise 4.6. You can then simply copy them and paste them in the cells below 😈</span>

# %% [markdown]
# <span style="color:dark green">  In the code below you'll that the argument `num_rows_per_file` contains 4,000,000 rows. This is because the merge in 4.6 isn't resulting in such an enormous dataframe as is has only 10 columns (plus the merge flag). However, if you're using this script for the merge in 4.9 you'll probably need to reduce the number of rows as the columns will be many more (20+) after all the aggregations. You can start with 1,000,000 rows, but if you keep getting an Error try fewer, for example 500,000 rows.  </span>

# %%
# %%time

# Save the terality dataframe to multiple parquet files
df_2.to_parquet_folder(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_*.parquet",
                      num_rows_per_file=4000000)
# Out:
# Wall time: 1min

# %%
# %%time

# Load these files into the memory

te_1 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet")
te_2 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet")
te_3 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet")
te_4 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet")
te_5 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet")
te_6 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet")
te_7 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet")
te_8 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet")
te_9 = te.read_parquet(path = "C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet")
# Out:
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:   1%| | 262k/38.3M [00:00<02:13, 285kB/
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:   1%| | 524k/38.3M [00:01<01:42, 370kB/
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:   5%| | 1.84M/38.3M [00:01<01:11, 512kB
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  10%| | 3.67M/38.3M [00:01<00:27, 1.26M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  10%| | 3.67M/38.3M [00:01<00:27, 1.26M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  10%| | 3.67M/38.3M [00:01<00:27, 1.26M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  12%| | 4.72M/38.3M [00:02<00:18, 1.82M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  12%| | 4.72M/38.3M [00:02<00:18, 1.82M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  15%|▏| 5.77M/38.3M [00:02<00:15, 2.15M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  18%|▏| 7.08M/38.3M [00:02<00:11, 2.64M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  22%|▏| 8.39M/38.3M [00:02<00:09, 3.22M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  25%|▎| 9.70M/38.3M [00:02<00:07, 3.87M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  29%|▎| 11.0M/38.3M [00:03<00:06, 4.39M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  31%|▎| 11.8M/38.3M [00:03<00:05, 4.60M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  33%|▎| 12.6M/38.3M [00:03<00:05, 4.60M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  36%|▎| 13.6M/38.3M [00:03<00:04, 5.30M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  38%|▍| 14.4M/38.3M [00:03<00:04, 5.84M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  40%|▍| 15.2M/38.3M [00:03<00:04, 5.43M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  42%|▍| 16.3M/38.3M [00:04<00:04, 5.42M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  45%|▍| 17.0M/38.3M [00:04<00:03, 5.85M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  47%|▍| 17.8M/38.3M [00:04<00:03, 5.15M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  49%|▍| 18.6M/38.3M [00:04<00:04, 4.88M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  51%|▌| 19.4M/38.3M [00:04<00:03, 5.33M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  53%|▌| 20.4M/38.3M [00:04<00:03, 5.34M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  55%|▌| 21.2M/38.3M [00:04<00:03, 4.90M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  57%|▌| 21.8M/38.3M [00:05<00:03, 4.48M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  59%|▌| 22.6M/38.3M [00:05<00:03, 3.96M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  59%|▌| 22.6M/38.3M [00:05<00:03, 3.96M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  60%|▌| 23.1M/38.3M [00:05<00:04, 3.65M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  62%|▌| 23.6M/38.3M [00:05<00:04, 3.39M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  63%|▋| 24.1M/38.3M [00:05<00:03, 3.65M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  64%|▋| 24.7M/38.3M [00:05<00:03, 3.68M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  66%|▋| 25.2M/38.3M [00:06<00:03, 3.68M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  67%|▋| 25.7M/38.3M [00:06<00:03, 3.74M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  69%|▋| 26.5M/38.3M [00:06<00:02, 4.47M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  69%|▋| 26.5M/38.3M [00:06<00:02, 4.47M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  71%|▋| 27.0M/38.3M [00:06<00:02, 4.27M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  72%|▋| 27.5M/38.3M [00:06<00:02, 4.50M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  74%|▋| 28.3M/38.3M [00:06<00:02, 4.68M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  77%|▊| 29.4M/38.3M [00:06<00:01, 5.20M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  77%|▊| 29.4M/38.3M [00:06<00:01, 5.20M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  79%|▊| 30.2M/38.3M [00:07<00:01, 4.51M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  82%|▊| 31.2M/38.3M [00:07<00:01, 5.13M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  84%|▊| 32.0M/38.3M [00:07<00:01, 5.18M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  86%|▊| 32.8M/38.3M [00:07<00:00, 5.55M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  88%|▉| 33.8M/38.3M [00:07<00:00, 5.32M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  89%|▉| 34.1M/38.3M [00:07<00:00, 5.78M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  89%|▉| 34.1M/38.3M [00:07<00:00, 5.78M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  91%|▉| 34.9M/38.3M [00:07<00:00, 5.43M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  93%|▉| 35.7M/38.3M [00:08<00:00, 5.28M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  95%|▉| 36.5M/38.3M [00:08<00:00, 4.38M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  97%|▉| 37.0M/38.3M [00:08<00:00, 3.05M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  98%|▉| 37.5M/38.3M [00:08<00:00, 2.42M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet:  99%|▉| 38.0M/38.3M [00:09<00:00, 2.18M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:   1%| | 262k/38.3M [00:00<00:43, 875kB/
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:   3%| | 1.31M/38.3M [00:00<00:31, 1.18M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:   7%| | 2.62M/38.3M [00:00<00:22, 1.58M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  10%| | 3.67M/38.3M [00:00<00:16, 2.11M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  12%| | 4.46M/38.3M [00:00<00:12, 2.68M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  14%|▏| 5.24M/38.3M [00:01<00:11, 2.89M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  16%|▏| 6.03M/38.3M [00:01<00:10, 3.05M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  19%|▏| 7.34M/38.3M [00:01<00:08, 3.61M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  22%|▏| 8.39M/38.3M [00:01<00:06, 4.39M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  24%|▏| 9.18M/38.3M [00:01<00:06, 4.79M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  26%|▎| 9.96M/38.3M [00:01<00:05, 4.97M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  28%|▎| 10.7M/38.3M [00:02<00:05, 4.79M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  30%|▎| 11.5M/38.3M [00:02<00:05, 5.02M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  32%|▎| 12.3M/38.3M [00:02<00:05, 4.95M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  34%|▎| 13.1M/38.3M [00:02<00:05, 4.56M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  37%|▎| 14.2M/38.3M [00:02<00:05, 4.68M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  40%|▍| 15.5M/38.3M [00:03<00:04, 4.99M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  44%|▍| 16.8M/38.3M [00:03<00:04, 5.27M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  47%|▍| 17.8M/38.3M [00:03<00:03, 5.88M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  49%|▍| 18.6M/38.3M [00:03<00:03, 5.21M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  51%|▌| 19.4M/38.3M [00:03<00:03, 4.72M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  54%|▌| 20.7M/38.3M [00:03<00:03, 5.19M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  57%|▌| 21.8M/38.3M [00:04<00:02, 5.76M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  59%|▌| 22.5M/38.3M [00:04<00:03, 5.22M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  61%|▌| 23.3M/38.3M [00:04<00:03, 4.93M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  63%|▋| 24.1M/38.3M [00:04<00:02, 5.11M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  65%|▋| 24.9M/38.3M [00:04<00:03, 4.44M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  66%|▋| 25.4M/38.3M [00:04<00:02, 4.60M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  68%|▋| 26.2M/38.3M [00:05<00:02, 5.20M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  71%|▋| 27.0M/38.3M [00:05<00:02, 4.89M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  73%|▋| 27.8M/38.3M [00:05<00:01, 5.52M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  75%|▊| 28.8M/38.3M [00:05<00:01, 5.63M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  75%|▊| 28.8M/38.3M [00:05<00:01, 5.63M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  77%|▊| 29.6M/38.3M [00:05<00:01, 5.15M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  79%|▊| 30.4M/38.3M [00:05<00:01, 4.94M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  82%|▊| 31.2M/38.3M [00:05<00:01, 5.38M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  84%|▊| 32.2M/38.3M [00:06<00:01, 5.66M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  86%|▊| 33.0M/38.3M [00:06<00:00, 5.73M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  88%|▉| 33.8M/38.3M [00:06<00:00, 5.73M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  90%|▉| 34.6M/38.3M [00:06<00:00, 5.81M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  92%|▉| 35.4M/38.3M [00:06<00:00, 6.06M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  95%|▉| 36.2M/38.3M [00:06<00:00, 5.78M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  97%|▉| 37.0M/38.3M [00:06<00:00, 5.42M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet:  99%|▉| 37.7M/38.3M [00:07<00:00, 4.08M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet: 100%|█| 38.3M/38.3M [00:07<00:00, 3.89M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   1%| | 262k/38.3M [00:00<01:01, 623kB/
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   2%| | 786k/38.3M [00:00<00:44, 843kB/
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   3%| | 1.05M/38.3M [00:00<00:32, 1.15M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   4%| | 1.57M/38.3M [00:00<00:25, 1.44M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   6%| | 2.36M/38.3M [00:00<00:19, 1.85M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:   8%| | 2.88M/38.3M [00:00<00:16, 2.15M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  10%| | 3.67M/38.3M [00:01<00:13, 2.57M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  11%| | 4.19M/38.3M [00:01<00:12, 2.77M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  14%|▏| 5.51M/38.3M [00:01<00:08, 3.83M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  14%|▏| 5.51M/38.3M [00:01<00:08, 3.83M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  14%|▏| 5.51M/38.3M [00:01<00:08, 3.83M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  16%|▏| 6.03M/38.3M [00:01<00:08, 3.85M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  17%|▏| 6.55M/38.3M [00:01<00:07, 4.08M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  18%|▏| 7.08M/38.3M [00:01<00:07, 4.01M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  20%|▏| 7.60M/38.3M [00:02<00:07, 4.00M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  22%|▏| 8.39M/38.3M [00:02<00:07, 4.21M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  24%|▏| 9.18M/38.3M [00:02<00:06, 4.84M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  26%|▎| 9.96M/38.3M [00:02<00:06, 4.19M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  28%|▎| 10.7M/38.3M [00:02<00:05, 4.70M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  29%|▎| 11.3M/38.3M [00:02<00:06, 4.14M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  32%|▎| 12.3M/38.3M [00:02<00:05, 4.76M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  35%|▎| 13.4M/38.3M [00:03<00:04, 5.49M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  37%|▎| 14.2M/38.3M [00:03<00:04, 5.96M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  39%|▍| 14.9M/38.3M [00:03<00:03, 6.21M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  42%|▍| 16.0M/38.3M [00:03<00:03, 6.27M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  44%|▍| 16.8M/38.3M [00:03<00:03, 6.05M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  46%|▍| 17.6M/38.3M [00:03<00:03, 5.42M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  48%|▍| 18.4M/38.3M [00:03<00:04, 4.85M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  49%|▍| 18.9M/38.3M [00:04<00:04, 4.62M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  51%|▌| 19.4M/38.3M [00:04<00:04, 4.28M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  53%|▌| 20.4M/38.3M [00:04<00:03, 4.96M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  55%|▌| 21.2M/38.3M [00:04<00:03, 4.51M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  58%|▌| 22.3M/38.3M [00:04<00:03, 5.07M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  60%|▌| 23.1M/38.3M [00:04<00:02, 5.61M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  63%|▋| 24.1M/38.3M [00:05<00:02, 5.61M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  65%|▋| 24.9M/38.3M [00:05<00:02, 5.84M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  68%|▋| 26.0M/38.3M [00:05<00:01, 6.52M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  70%|▋| 26.8M/38.3M [00:05<00:02, 5.68M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  72%|▋| 27.5M/38.3M [00:05<00:02, 4.95M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  74%|▋| 28.3M/38.3M [00:05<00:01, 5.44M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  76%|▊| 29.1M/38.3M [00:05<00:01, 4.92M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  78%|▊| 29.9M/38.3M [00:06<00:01, 5.00M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  80%|▊| 30.7M/38.3M [00:06<00:01, 5.38M
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_1.parquet: 100%|█| 38.3M/38.3M [00:28<00:00, 2.18M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  82%|▊| 31.5M/38.3M [00:06<00:01, 5.21M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  84%|▊| 32.3M/38.3M [00:06<00:01, 4.99M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  87%|▊| 33.3M/38.3M [00:06<00:01, 4.87M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  89%|▉| 34.1M/38.3M [00:07<00:00, 4.66M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  91%|▉| 34.9M/38.3M [00:07<00:00, 4.46M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  93%|▉| 35.7M/38.3M [00:07<00:00, 4.51M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  95%|▉| 36.5M/38.3M [00:07<00:00, 4.66M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  97%|▉| 37.0M/38.3M [00:07<00:00, 4.03M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  98%|▉| 37.5M/38.3M [00:07<00:00, 3.79M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet:  99%|▉| 38.0M/38.3M [00:08<00:00, 3.41M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:   0%|      | 0.00/38.2M [00:00<?, ?B/s]
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:   1%| | 262k/38.2M [00:00<00:56, 670kB/
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:   3%| | 1.31M/38.2M [00:00<00:39, 930kB
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:   5%| | 1.84M/38.2M [00:00<00:30, 1.19M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:   8%| | 2.88M/38.2M [00:00<00:22, 1.57M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  10%| | 3.93M/38.2M [00:01<00:17, 2.00M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  14%|▏| 5.24M/38.2M [00:01<00:12, 2.55M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  17%|▏| 6.55M/38.2M [00:01<00:10, 3.09M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  18%|▏| 6.82M/38.2M [00:01<00:08, 3.74M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  20%|▏| 7.60M/38.2M [00:01<00:07, 4.20M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  23%|▏| 8.65M/38.2M [00:01<00:05, 4.99M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  25%|▏| 9.44M/38.2M [00:01<00:06, 4.49M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  27%|▎| 10.2M/38.2M [00:02<00:06, 4.41M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  29%|▎| 11.0M/38.2M [00:02<00:05, 4.75M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  32%|▎| 12.1M/38.2M [00:02<00:05, 4.66M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  34%|▎| 13.1M/38.2M [00:02<00:05, 4.99M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  36%|▎| 13.9M/38.2M [00:02<00:06, 4.00M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  38%|▍| 14.4M/38.2M [00:03<00:07, 3.24M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  38%|▍| 14.7M/38.2M [00:03<00:07, 3.28M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  40%|▍| 15.2M/38.2M [00:03<00:06, 3.68M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  41%|▍| 15.7M/38.2M [00:03<00:05, 3.87M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  43%|▍| 16.3M/38.2M [00:03<00:05, 3.78M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  45%|▍| 17.0M/38.2M [00:03<00:04, 4.31M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  47%|▍| 17.8M/38.2M [00:03<00:04, 4.58M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  47%|▍| 17.8M/38.2M [00:03<00:04, 4.58M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  49%|▍| 18.6M/38.2M [00:03<00:04, 4.74M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  50%|▌| 19.1M/38.2M [00:04<00:03, 4.85M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  52%|▌| 19.9M/38.2M [00:04<00:03, 5.24M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  54%|▌| 20.7M/38.2M [00:04<00:03, 5.61M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  56%|▌| 21.5M/38.2M [00:04<00:03, 5.51M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  59%|▌| 22.5M/38.2M [00:04<00:02, 6.23M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  61%|▌| 23.3M/38.2M [00:04<00:02, 5.76M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  63%|▋| 24.1M/38.2M [00:04<00:02, 5.82M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  65%|▋| 24.9M/38.2M [00:04<00:02, 5.98M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  68%|▋| 25.9M/38.2M [00:05<00:02, 6.07M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  70%|▋| 26.7M/38.2M [00:05<00:02, 5.59M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  72%|▋| 27.5M/38.2M [00:05<00:02, 5.11M
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_2.parquet: 100%|█| 38.3M/38.3M [00:26<00:00, 3.89M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  74%|▋| 28.3M/38.2M [00:05<00:02, 4.98M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  76%|▊| 29.1M/38.2M [00:05<00:01, 5.23M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  78%|▊| 29.9M/38.2M [00:05<00:01, 5.58M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  80%|▊| 30.6M/38.2M [00:05<00:01, 5.91M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  82%|▊| 31.4M/38.2M [00:06<00:01, 5.90M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  84%|▊| 32.2M/38.2M [00:06<00:01, 5.52M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  85%|▊| 32.5M/38.2M [00:06<00:01, 5.76M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  87%|▊| 33.3M/38.2M [00:06<00:01, 4.79M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  89%|▉| 34.0M/38.2M [00:06<00:00, 4.60M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  92%|▉| 35.1M/38.2M [00:06<00:00, 4.74M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  95%|▉| 36.1M/38.2M [00:07<00:00, 4.99M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  97%|▉| 36.9M/38.2M [00:07<00:00, 4.95M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  98%|▉| 37.5M/38.2M [00:07<00:00, 4.37M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet:  99%|▉| 38.0M/38.2M [00:07<00:00, 4.03M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:   1%| | 262k/38.3M [00:00<00:50, 752kB/
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:   4%| | 1.57M/38.3M [00:00<00:35, 1.03M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:   8%| | 2.88M/38.3M [00:00<00:25, 1.38M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  10%| | 3.93M/38.3M [00:00<00:18, 1.84M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  12%| | 4.72M/38.3M [00:01<00:14, 2.26M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  14%|▏| 5.24M/38.3M [00:01<00:12, 2.71M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  16%|▏| 6.03M/38.3M [00:01<00:09, 3.24M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  18%|▏| 6.82M/38.3M [00:01<00:08, 3.73M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  20%|▏| 7.60M/38.3M [00:01<00:07, 4.08M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  22%|▏| 8.39M/38.3M [00:01<00:06, 4.65M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  24%|▏| 9.18M/38.3M [00:01<00:07, 4.08M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  26%|▎| 9.96M/38.3M [00:02<00:06, 4.33M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  28%|▎| 10.7M/38.3M [00:02<00:06, 4.42M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  30%|▎| 11.5M/38.3M [00:02<00:05, 4.67M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  32%|▎| 12.3M/38.3M [00:02<00:04, 5.31M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  34%|▎| 13.1M/38.3M [00:02<00:04, 5.71M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  36%|▎| 13.9M/38.3M [00:02<00:04, 5.49M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  38%|▍| 14.7M/38.3M [00:02<00:04, 5.24M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  42%|▍| 16.0M/38.3M [00:03<00:03, 5.75M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  44%|▍| 16.8M/38.3M [00:03<00:03, 5.38M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  46%|▍| 17.6M/38.3M [00:03<00:04, 4.70M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  48%|▍| 18.4M/38.3M [00:03<00:04, 4.67M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  51%|▌| 19.7M/38.3M [00:03<00:03, 4.79M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  54%|▌| 20.7M/38.3M [00:04<00:03, 5.24M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  57%|▌| 21.8M/38.3M [00:04<00:02, 5.78M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  60%|▌| 22.8M/38.3M [00:04<00:02, 5.67M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  62%|▌| 23.6M/38.3M [00:04<00:02, 6.17M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  64%|▋| 24.4M/38.3M [00:04<00:02, 5.01M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  66%|▋| 25.4M/38.3M [00:04<00:02, 5.27M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  69%|▋| 26.2M/38.3M [00:05<00:02, 5.30M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  71%|▋| 27.0M/38.3M [00:05<00:02, 5.36M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  73%|▋| 27.8M/38.3M [00:05<00:02, 5.04M
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_3.parquet: 100%|█| 38.3M/38.3M [00:26<00:00, 3.41M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  75%|▋| 28.6M/38.3M [00:05<00:01, 5.13M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  77%|▊| 29.3M/38.3M [00:05<00:01, 5.45M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  79%|▊| 30.1M/38.3M [00:05<00:01, 5.05M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  81%|▊| 30.9M/38.3M [00:05<00:01, 4.92M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  83%|▊| 31.7M/38.3M [00:06<00:01, 5.31M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  85%|▊| 32.5M/38.3M [00:06<00:00, 5.78M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  87%|▊| 33.3M/38.3M [00:06<00:00, 5.22M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  89%|▉| 34.1M/38.3M [00:06<00:00, 5.10M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  92%|▉| 35.1M/38.3M [00:06<00:00, 4.87M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  92%|▉| 35.1M/38.3M [00:06<00:00, 4.87M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  93%|▉| 35.6M/38.3M [00:06<00:00, 4.11M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  95%|▉| 36.2M/38.3M [00:07<00:00, 4.26M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  96%|▉| 36.7M/38.3M [00:07<00:00, 4.12M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  97%|▉| 37.2M/38.3M [00:07<00:00, 3.00M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet:  99%|▉| 37.7M/38.3M [00:07<00:00, 2.55M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet: 100%|█| 38.3M/38.3M [00:08<00:00, 2.27M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   1%| | 262k/38.3M [00:00<00:46, 822kB/
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   3%| | 1.31M/38.3M [00:00<00:32, 1.13M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   5%| | 1.84M/38.3M [00:00<00:24, 1.46M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   5%| | 2.10M/38.3M [00:00<00:18, 1.91M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:   8%| | 2.88M/38.3M [00:00<00:16, 2.12M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  10%| | 3.93M/38.3M [00:00<00:12, 2.65M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  13%|▏| 4.98M/38.3M [00:01<00:09, 3.41M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  15%|▏| 5.77M/38.3M [00:01<00:08, 4.01M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  17%|▏| 6.55M/38.3M [00:01<00:08, 3.79M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  19%|▏| 7.34M/38.3M [00:01<00:07, 4.16M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  22%|▏| 8.39M/38.3M [00:01<00:06, 4.70M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  22%|▏| 8.39M/38.3M [00:01<00:06, 4.70M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  25%|▏| 9.44M/38.3M [00:01<00:05, 4.99M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  27%|▎| 10.2M/38.3M [00:02<00:05, 4.99M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  29%|▎| 11.0M/38.3M [00:02<00:05, 5.37M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  31%|▎| 11.8M/38.3M [00:02<00:05, 4.79M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  33%|▎| 12.6M/38.3M [00:02<00:04, 5.38M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  35%|▎| 13.4M/38.3M [00:02<00:04, 5.54M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  37%|▎| 14.2M/38.3M [00:02<00:04, 5.26M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  39%|▍| 14.9M/38.3M [00:02<00:04, 5.27M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  41%|▍| 15.7M/38.3M [00:03<00:04, 5.43M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  43%|▍| 16.5M/38.3M [00:03<00:04, 5.43M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  45%|▍| 17.3M/38.3M [00:03<00:04, 5.02M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  47%|▍| 18.1M/38.3M [00:03<00:03, 5.39M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  49%|▍| 18.9M/38.3M [00:03<00:03, 5.38M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  52%|▌| 19.9M/38.3M [00:03<00:03, 4.95M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  52%|▌| 19.9M/38.3M [00:03<00:03, 4.95M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  54%|▌| 20.7M/38.3M [00:03<00:03, 5.20M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  56%|▌| 21.5M/38.3M [00:04<00:02, 5.61M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  58%|▌| 22.3M/38.3M [00:04<00:03, 4.94M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  60%|▌| 22.8M/38.3M [00:04<00:03, 4.61M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  61%|▌| 23.3M/38.3M [00:04<00:03, 4.67M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  62%|▌| 23.9M/38.3M [00:04<00:03, 4.36M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  65%|▋| 24.9M/38.3M [00:04<00:02, 4.49M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  67%|▋| 25.7M/38.3M [00:05<00:02, 4.43M
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_4.parquet: 100%|█| 38.2M/38.2M [00:25<00:00, 4.03M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  71%|▋| 27.0M/38.3M [00:05<00:02, 5.11M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  71%|▋| 27.0M/38.3M [00:05<00:02, 5.11M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  73%|▋| 27.8M/38.3M [00:05<00:02, 4.82M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  73%|▋| 28.0M/38.3M [00:05<00:02, 5.04M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  75%|▋| 28.6M/38.3M [00:05<00:02, 4.65M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  76%|▊| 29.1M/38.3M [00:05<00:01, 4.79M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  78%|▊| 29.9M/38.3M [00:05<00:01, 5.22M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  80%|▊| 30.7M/38.3M [00:05<00:01, 4.81M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  82%|▊| 31.5M/38.3M [00:06<00:01, 4.99M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  84%|▊| 32.0M/38.3M [00:06<00:01, 3.98M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  85%|▊| 32.5M/38.3M [00:06<00:01, 4.00M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  86%|▊| 32.8M/38.3M [00:06<00:01, 4.43M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  87%|▊| 33.3M/38.3M [00:06<00:01, 3.39M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  89%|▉| 34.1M/38.3M [00:06<00:01, 4.03M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  90%|▉| 34.6M/38.3M [00:07<00:01, 2.91M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  92%|▉| 35.1M/38.3M [00:07<00:01, 3.14M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  93%|▉| 35.7M/38.3M [00:07<00:00, 3.57M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  95%|▉| 36.2M/38.3M [00:07<00:00, 3.68M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  96%|▉| 36.7M/38.3M [00:07<00:00, 3.89M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  97%|▉| 37.2M/38.3M [00:07<00:00, 3.53M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet:  99%|▉| 37.7M/38.3M [00:08<00:00, 2.68M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet: 100%|█| 38.3M/38.3M [00:08<00:00, 2.22M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   1%| | 262k/38.3M [00:00<00:46, 820kB/
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   1%| | 524k/38.3M [00:00<00:39, 964kB/
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   4%| | 1.57M/38.3M [00:00<00:22, 1.67M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   4%| | 1.57M/38.3M [00:00<00:22, 1.67M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   8%| | 2.88M/38.3M [00:00<00:13, 2.62M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:   8%| | 2.88M/38.3M [00:00<00:13, 2.62M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  10%| | 3.93M/38.3M [00:00<00:11, 3.11M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  14%|▏| 5.24M/38.3M [00:01<00:09, 3.63M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  17%|▏| 6.55M/38.3M [00:01<00:08, 3.61M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  19%|▏| 7.34M/38.3M [00:01<00:07, 4.30M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  21%|▏| 8.13M/38.3M [00:01<00:06, 4.41M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  23%|▏| 8.91M/38.3M [00:01<00:06, 4.54M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  25%|▎| 9.70M/38.3M [00:02<00:05, 5.16M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  27%|▎| 10.5M/38.3M [00:02<00:05, 5.03M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  28%|▎| 10.7M/38.3M [00:02<00:05, 5.36M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  30%|▎| 11.5M/38.3M [00:02<00:06, 4.08M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  31%|▎| 12.1M/38.3M [00:02<00:06, 3.75M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  33%|▎| 12.6M/38.3M [00:02<00:06, 4.08M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  35%|▎| 13.4M/38.3M [00:02<00:05, 4.18M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  36%|▎| 13.9M/38.3M [00:03<00:05, 4.41M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  38%|▍| 14.7M/38.3M [00:03<00:04, 5.03M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  40%|▍| 15.5M/38.3M [00:03<00:04, 5.27M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  42%|▍| 16.3M/38.3M [00:03<00:03, 5.64M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  45%|▍| 17.0M/38.3M [00:03<00:03, 5.36M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  45%|▍| 17.3M/38.3M [00:03<00:03, 5.64M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  47%|▍| 18.1M/38.3M [00:03<00:03, 5.74M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  49%|▍| 18.9M/38.3M [00:03<00:03, 5.60M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  51%|▌| 19.7M/38.3M [00:03<00:03, 5.50M
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_5.parquet: 100%|█| 38.3M/38.3M [00:25<00:00, 2.27M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  53%|▌| 20.4M/38.3M [00:04<00:03, 4.90M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  55%|▌| 21.2M/38.3M [00:04<00:03, 5.14M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  58%|▌| 22.0M/38.3M [00:04<00:03, 5.24M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  60%|▌| 22.8M/38.3M [00:04<00:02, 5.35M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  62%|▌| 23.6M/38.3M [00:04<00:02, 5.43M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  64%|▋| 24.6M/38.3M [00:04<00:02, 6.26M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  66%|▋| 25.4M/38.3M [00:04<00:02, 5.97M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  69%|▋| 26.2M/38.3M [00:05<00:02, 5.12M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  71%|▋| 27.0M/38.3M [00:05<00:02, 5.21M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  73%|▋| 27.8M/38.3M [00:05<00:02, 5.21M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  75%|▋| 28.6M/38.3M [00:05<00:01, 5.22M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  77%|▊| 29.4M/38.3M [00:05<00:01, 5.07M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  78%|▊| 29.9M/38.3M [00:05<00:01, 4.79M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  81%|▊| 30.9M/38.3M [00:06<00:01, 5.10M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  83%|▊| 31.7M/38.3M [00:06<00:01, 5.63M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  86%|▊| 32.8M/38.3M [00:06<00:01, 5.43M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  88%|▉| 33.8M/38.3M [00:06<00:00, 5.50M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  91%|▉| 34.9M/38.3M [00:06<00:00, 5.82M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  93%|▉| 35.7M/38.3M [00:06<00:00, 6.05M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  95%|▉| 36.5M/38.3M [00:07<00:00, 5.30M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  97%|▉| 37.2M/38.3M [00:07<00:00, 4.61M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet:  99%|▉| 37.8M/38.3M [00:07<00:00, 4.08M
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet: 100%|█| 38.3M/38.3M [00:07<00:00, 3.73M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:   0%|      | 0.00/38.3M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:   1%| | 262k/38.3M [00:00<00:48, 781kB/
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:   4%| | 1.57M/38.3M [00:00<00:34, 1.07M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:   8%| | 2.88M/38.3M [00:00<00:24, 1.43M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  11%| | 4.19M/38.3M [00:00<00:18, 1.89M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  14%|▏| 5.51M/38.3M [00:01<00:13, 2.34M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  16%|▏| 6.29M/38.3M [00:01<00:11, 2.77M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  18%|▏| 7.08M/38.3M [00:01<00:09, 3.25M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  20%|▏| 7.60M/38.3M [00:01<00:09, 3.34M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  21%|▏| 7.86M/38.3M [00:01<00:08, 3.68M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  23%|▏| 8.65M/38.3M [00:01<00:07, 3.82M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  25%|▎| 9.70M/38.3M [00:01<00:06, 4.62M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  27%|▎| 10.5M/38.3M [00:02<00:05, 5.08M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  29%|▎| 11.3M/38.3M [00:02<00:06, 4.39M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  32%|▎| 12.3M/38.3M [00:02<00:04, 5.21M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  34%|▎| 13.1M/38.3M [00:02<00:05, 4.79M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  36%|▎| 13.9M/38.3M [00:02<00:05, 4.77M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  38%|▍| 14.7M/38.3M [00:02<00:04, 5.29M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  41%|▍| 15.7M/38.3M [00:02<00:03, 5.65M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  43%|▍| 16.5M/38.3M [00:03<00:04, 5.31M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  45%|▍| 17.3M/38.3M [00:03<00:04, 4.27M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  47%|▍| 17.8M/38.3M [00:03<00:05, 3.76M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  48%|▍| 18.4M/38.3M [00:03<00:04, 4.07M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  50%|▍| 19.1M/38.3M [00:03<00:04, 4.76M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  52%|▌| 20.0M/38.3M [00:04<00:04, 4.56M
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_6.parquet: 100%|█| 38.3M/38.3M [00:25<00:00, 2.22M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  53%|▌| 20.5M/38.3M [00:04<00:04, 3.86M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  56%|▌| 21.3M/38.3M [00:04<00:04, 4.07M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  58%|▌| 22.0M/38.3M [00:04<00:03, 4.50M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  60%|▌| 22.8M/38.3M [00:04<00:03, 4.58M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  62%|▌| 23.6M/38.3M [00:04<00:02, 5.05M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  64%|▋| 24.4M/38.3M [00:04<00:02, 5.07M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  66%|▋| 25.2M/38.3M [00:05<00:02, 5.51M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  68%|▋| 26.0M/38.3M [00:05<00:02, 5.44M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  70%|▋| 26.8M/38.3M [00:05<00:02, 5.05M
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  72%|▋| 27.6M/38.3M [00:05<00:01, 5.51M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  74%|▋| 28.3M/38.3M [00:05<00:01, 5.56M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  76%|▊| 29.1M/38.3M [00:05<00:01, 5.84M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  78%|▊| 29.9M/38.3M [00:05<00:01, 5.87M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  80%|▊| 30.7M/38.3M [00:06<00:01, 6.06M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  82%|▊| 31.5M/38.3M [00:06<00:01, 6.25M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  84%|▊| 32.3M/38.3M [00:06<00:00, 6.42M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  86%|▊| 33.1M/38.3M [00:06<00:00, 6.49M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  88%|▉| 33.8M/38.3M [00:06<00:00, 5.44M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  90%|▉| 34.6M/38.3M [00:06<00:00, 5.98M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  92%|▉| 35.4M/38.3M [00:06<00:00, 5.58M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  95%|▉| 36.2M/38.3M [00:06<00:00, 5.26M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  97%|▉| 37.0M/38.3M [00:07<00:00, 4.43M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  98%|▉| 37.5M/38.3M [00:07<00:00, 4.07M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet:  99%|▉| 38.0M/38.3M [00:07<00:00, 3.98M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:   0%|      | 0.00/4.34M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:   6%| | 262k/4.34M [00:00<00:03, 1.08MB
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  12%| | 524k/4.34M [00:00<00:03, 1.23MB
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  18%|▏| 786k/4.34M [00:00<00:02, 1.38MB
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  24%|▏| 1.05M/4.34M [00:00<00:02, 1.52M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  30%|▎| 1.31M/4.34M [00:00<00:01, 1.55M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  36%|▎| 1.57M/4.34M [00:00<00:01, 1.64M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  42%|▍| 1.84M/4.34M [00:01<00:01, 1.73M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  48%|▍| 2.10M/4.34M [00:01<00:01, 1.74M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  54%|▌| 2.36M/4.34M [00:01<00:01, 1.79M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  60%|▌| 2.62M/4.34M [00:01<00:00, 1.86M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  67%|▋| 2.88M/4.34M [00:01<00:00, 1.82M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  73%|▋| 3.15M/4.34M [00:01<00:00, 1.79M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  79%|▊| 3.41M/4.34M [00:01<00:00, 1.84M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  85%|▊| 3.67M/4.34M [00:02<00:00, 1.79M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet:  91%|▉| 3.93M/4.34M [00:02<00:00, 1.85M
#
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_9.parquet: 100%|█| 4.34M/4.34M [00:02<00:00, 1.70M
# Wall time: 1min 28s

# %%
# %%time

# Convert the parquets to pandas dataframes

df_pd_roundtrip_1 = te_1.to_pandas()
df_pd_roundtrip_2 = te_2.to_pandas()
df_pd_roundtrip_3 = te_3.to_pandas()
df_pd_roundtrip_4 = te_4.to_pandas()
df_pd_roundtrip_5 = te_5.to_pandas()
df_pd_roundtrip_6 = te_6.to_pandas()
df_pd_roundtrip_7 = te_7.to_pandas()
df_pd_roundtrip_8 = te_8.to_pandas()
df_pd_roundtrip_9 = te_9.to_pandas()
# Out:
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_7.parquet: 100%|█| 38.3M/38.3M [00:24<00:00, 3.73M
#
#
#
#
#
#
#
#
# C:/Users/asus/Documents/Instacart Basket Analysis/order_prior_merged_8.parquet: 100%|█| 38.3M/38.3M [00:24<00:00, 3.98M
# Wall time: 1min 47s

# %%
# %%time

# Concatinate the dataframes 

frames = [
df_pd_roundtrip_1,
df_pd_roundtrip_2 ,
df_pd_roundtrip_3 ,
df_pd_roundtrip_4 ,
df_pd_roundtrip_5 ,
df_pd_roundtrip_6 ,
df_pd_roundtrip_7 ,
df_pd_roundtrip_8 ,
df_pd_roundtrip_9 ]

df_concat = pd.concat(frames)
# Out:
# Wall time: 381 ms

# %%
#Check the shape

df_concat.shape
# Out:
# (11101161, 10)

# %%
# Check the head

df_concat.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1         2       28985                  2          1   202279             3
# 2         2        9327                  3          0   202279             3
# 3         2       45918                  4          1   202279             3
# 4         2       30035                  5          0   202279             3
#
#    orders_day_of_week  order_time_of_day  days_since_prior_order _merge
# 0                   5                  9                     8.0   both
# 1                   5                  9                     8.0   both
# 2                   5                  9                     8.0   both
# 3                   5                  9                     8.0   both
# 4                   5                  9                     8.0   both

# %%
# Check out info

df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11101161 entries, 0 to 32434488
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   product_id              int32
#  2   add_to_cart_order       int32
#  3   reordered               int8
#  4   user_id                 int64
#  5   order_number            int64
#  6   orders_day_of_week      int64
#  7   order_time_of_day       int64
#  8   days_since_prior_order  float64
#  9   _merge                  category
# dtypes: category(1), float64(1), int32(2), int64(5), int8(1)
# memory usage: 698.7 MB

# %% [markdown]
# ## Success! 🥳
